# %%
# The order of checks and imports matter
import  os
from dotenv import load_dotenv

from browser import ChromeBrowser

load_dotenv()

assert os.getenv("CHROME_USER_DATA_DIR", None)
if not os.environ.get("CHROME_USER_DATA_DIR") or not os.environ.get("DEEPSEEK_EMAIL"):
    print("os.environ.get('CHROME_USER_DATA_DIR')", os.environ.get("CHROME_USER_DATA_DIR"))
    print("os.environ.get('DEEPSEEK_EMAIL')", os.environ.get("DEEPSEEK_EMAIL"))
    raise EnvironmentError("Browser cache is not set up.")

from browser.llms.session import ChatGPT
from browser.search.web import BraveBrowser
from browser.llms.session import DeepSeek

# %%
browser = ChromeBrowser()
# browser.driver.options.__dict__
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 browser = ChromeBrowser()
#       2 # browser.driver.options.__dict__
#
# File ~/pdev/freelectron/free-generalist/src/browser/browser.py:48, in ChromeBrowser.__init__(self, profile)
#      46 self.options = self.get_default_options()
#      47 self.profile = profile if profile else default_profile_directory_name
# ---> 48 self.driver = uc.Chrome(
#      49     options=self.options,
#      50     user_data_dir=os.path.join(self.chrome_user_data_dir, self.profile),
#      51 )
#      52 self.waiter = WebDriverWait(driver=self.driver, timeout=self.waiter_default_timeout)
#      53 self.actions = ActionChains(self.driver)
#
# ...

# %%
## LLM test
closed_ai = ChatGPT(browser, session_id="closed_ai")
closed_ai.send_message("Please just write a single sentence in Portuguese")

# %%
## Search test
search_browser = BraveBrowser(browser, "test_search")
ans_prussia = search_browser.search("History of Prussia",1)

# %%
# test switching tabs back and forth
new_search_browser = BraveBrowser(browser, "new_test_search")
new_search_browser.browser.wait(2)

# %%
# Between browsing sessions
ans_ai = new_search_browser.search("How do ai transformers work")
new_search_browser.browser.wait(2)
ans_bitcoin = search_browser.search("Bitcoin price")
print(search_browser.browser.opened_tabs)

# Back to llm
closed_ai.send_message("Please do technical analysis on bitcoin prices")

# %%
ans_prussia = search_browser.search("Gonka AI")

# %%
closed_ai.send_message("Please do technical analysis on bitcoin prices")

# %%
# Check DeepSeek
deepseek = DeepSeek(browser, session_id="deep")

deepseek.send_message("What are you trained on?")

# %%
deepseek.send_message("Run technical analysis on bitcoin price chart")

# %%
deepseek.past_questions_answers
